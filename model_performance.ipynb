# %% [markdown]
# ## Model Performance

# %% [markdown]
# <br><br>

# %%
import json
import pandas as pd
from pandas import option_context

# %%
performance_df = pd.read_csv("korean_output/BPUAZ (small-all) (04-16 18:17)/evaluation_log.csv")

with option_context('display.max_row', None) and option_context('display.max_colwidth', None):
    display(performance_df)
# Out:
#     Epoch    Bleu  Sacrebleu  Rouge 1  Rouge 2  Rouge L  Rouge Lsum  Meteor  \
# 0       0  0.0000     0.0000   0.0000   0.0000   0.0000      0.0000  0.0000
# 1       1  0.5019    50.7839  23.3302  14.0262  23.2822     23.3159  0.5078
# 2       2  0.5566    55.3837  25.9408  15.2886  25.8903     25.9130  0.5423
# 3       3  0.5752    57.7668  27.7717  16.2072  27.7339     27.7517  0.5652
# 4       4  0.5922    59.0537  28.3984  16.4532  28.3630     28.3712  0.5765
# 5       5  0.5938    59.4737  28.7472  16.5134  28.6866     28.7049  0.5814
# 6       6  0.6043    60.2555  29.1567  16.9279  29.1168     29.1500  0.5846
# 7       7  0.6120    60.9419  29.6655  17.0656  29.6441     29.6507  0.5896
# 8       8  0.6087    61.1941  29.7434  17.0829  29.7051     29.7229  0.5931
# 9       9  0.6134    61.4916  29.8496  17.2395  29.8082     29.8309  0.5935
# 10     10  0.6136    61.4515  29.9885  17.3305  29.9525     29.9606  0.5936
# ...

# %%
detokenized_output_df = pd.read_csv("korean_output/BPUAZ (small-all) (04-16 18:17)/detokenized_outputs_17.csv")

with option_context('display.max_row', None):
    with option_context('display.max_colwidth', None):
        display(detokenized_output_df)
